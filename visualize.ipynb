# %%
from grapher import Graph

# %%
course_graph = Graph("2021-2022")
# Out:
# Warning: a file already exists at 'data/2021-2022/course_ids.json'.Last modified: 1639456676.7471135Created: 1639388088.8665154
# No new data was cached.
# Warning: a file already exists at 'data/2021-2022/departments.json'.Last modified: 1639432687.8413637Created: 1639432687.8410428
# No new data was cached.
# Warning: a file already exists at 'data/2021-2022/prereqs.json'.Last modified: 1639548271.49724Created: 1639548271.4899743
# No new data was cached.

# %%
course_graph.graph_dept("School of Humanities & Sciences", "MATH")
