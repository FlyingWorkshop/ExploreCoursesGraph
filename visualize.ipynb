# %%
from grapher import Graph

# %%
course_graph = Graph("2021-2022", lazy=True)
# Out:
# No new data was cached.
# No new data was cached.
# No new data was cached.
# No new data was cached.

# %%
course_graph.graph_depts("MATH", "PHYSICS", save_file=True)
