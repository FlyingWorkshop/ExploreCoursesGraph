# %%
from grapher import Graph

# %%
course_graph = Graph("2021-2022")
# Out:
# ...
# Last modified: 2021-12-15-21:20
# Created: 2021-12-13-01:34
# No new data was cached.
# ...
# Last modified: 2021-12-13-13:58
# Created: 2021-12-13-13:58
# No new data was cached.
# ...
# Last modified: 2021-12-14-22:04
# Created: 2021-12-14-22:04
# No new data was cached.
# ...
# Last modified: 2021-12-15-21:08
# Created: 2021-12-15-21:08
# No new data was cached.

# %%
course_graph.graph_depts("ECON")
